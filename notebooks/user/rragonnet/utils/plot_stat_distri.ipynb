# %%
from scipy import stats
from numpy import linspace, exp
import matplotlib.pyplot as plt

# %%
distri = stats.norm(loc=0, scale=1.)

x_min, x_max = distri.ppf(.01), distri.ppf(.99)

# %%
x = linspace(x_min, x_max, 1000)
fig, ax = plt.subplots(1, 1)
ax.plot(x, distri.pdf(x),
       'b-', lw=2, alpha=0.6)

ax.fill_between(x, distri.pdf(x),
       alpha=0.4)

# %%
distri = stats.norm(loc=0, scale=1.)

y = distri.rvs(10000)
fig, ax = plt.subplots()

ax.hist(exp(y), bins=100)
ax.set_xlim((0, 10))
# Out:
# (0.0, 10.0)

# %%
y
# Out:
# array([ 2.01763954,  0.05573032, -1.58899722,  0.81065151, -0.9416756 ,
#        -0.53222212,  1.72277864, -0.50771935,  0.72819119,  0.68643064])
