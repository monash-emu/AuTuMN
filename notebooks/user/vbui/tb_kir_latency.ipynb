# %%
import warnings
from typing import List

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from autumn.core.inputs.database import get_input_db
from autumn.core.inputs.demography.queries import get_population_by_agegroup
from autumn.core.project import ParameterSet, get_project

# %%
warnings.filterwarnings("ignore")

# %%
project = get_project("tb_dynamics", "kiribati")

# %%
base_params = project.param_set.baseline

# %%
base_params
# Out:
# Params{'time': {'start': 1950.0, 'end': 2020.0, 'step': 0.1}, 'iso3': 'KIR', 'crude_birth_rate': 1.0, 'start_population_size': 33048.0, 'infectious_seed': 1.0, 'age_breakpoints': [0, 5, 15, 35, 50], 'age_mixing': {'type': 'extrapolated', 'source_iso3': 'FJI', 'age_adjust': True}, 'contact_rate': 1.4, 'age_specific_latency': {'early_activation': {0: 0.0066, 5: 0.0027, 15: 0.00027}, 'stabilisation': {0: 0.012, 5: 0.012, 15: 0.0054}, 'late_activation': {0: 1.9e-11, 5: 6.4e-06, 15: 3.3e-06}}, 'rr_infection_latent': 0.21, 'rr_infection_recovered': 1.0, 'progression_multiplier': 1.0, 'crude_death_rate': 1.0, 'description': None}

# %%
model_0 = project.run_baseline_model(base_params)

# %%
derived_df_0 = model_0.get_derived_outputs_df()

# %%
derived_df_0
# Out:
#         population_size  percentage_latent
# 1950.0     33048.000000           0.000000
# 1950.1     33076.633022           0.000410
# 1950.2     33106.166079           0.000803
# 1950.3     33136.583719           0.001186
# 1950.4     33167.870780           0.001567
# ...                 ...                ...
# 2019.6    108939.722915          66.806323
# 2019.7    109085.645003          66.872481
# 2019.8    109231.641912          66.936502
# 2019.9    109377.714531          66.998873
# 2020.0    109523.863747          67.059712
#
# [701 rows x 2 columns]

# %%
fig = px.line(derived_df_0, x=derived_df_0.index, y="percentage_latent")

# %%
fig.show()
