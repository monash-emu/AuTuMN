# %%
import warnings
from typing import List

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from autumn.core.inputs.database import get_input_db
from autumn.core.inputs.demography.queries import get_population_by_agegroup
from autumn.core.project import ParameterSet, get_project
from autumn.core.utils.display import pretty_print

# %%
warnings.filterwarnings("ignore")

# %%
project = get_project("tb_dynamics", "kiribati")

# %%
base_params = project.param_set.baseline

# %%
pretty_print(base_params)
# Out:
# Params
# { 'age_breakpoints': [0, 5, 15, 35, 50],
#   'age_mixing': {'age_adjust': True, 'source_iso3': 'FJI'},
#   'age_specific_latency': { 'early_activation': { 0: 0.0066,
#                                                   5: 0.0027,
#                                                   15: 0.00027},
#                             'late_activation': { 0: 1.9e-11,
#                                                  5: 6.4e-06,
#                                                  15: 3.3e-06},
#                             'stabilisation': {0: 0.012, 5: 0.012, 15: 0.0054}},
#   'contact_rate': 0.00178,
#   'crude_birth_rate': 1.0,
#   'crude_death_rate': 1.0,
#   'cumulative_start_time': 1950.0,
#   'description': None,
#   'infect_death_rate': 0.2,
#   'infectious_seed': 1.0,
#   'iso3': 'KIR',
#   'progression_multiplier': 1.0,
#   'rr_infection_latent': 0.21,
#   'rr_infection_recovered': 1.0,
#   'self_recovery_rate': 0.2,
#   'start_population_size': 33048.0,
#   'time': {'end': 2020.0, 'start': 1950.0, 'step': 0.1}}

# %%
model_0 = project.run_baseline_model(base_params)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\autumn\AuTuMN\notebooks\user\vbui\tb_kir_trans.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/autumn/AuTuMN/notebooks/user/vbui/tb_kir_trans.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> model_0 = project.run_baseline_model(base_params)
#
# File C:\autumn\AuTuMN\autumn\core\project\project.py:84, in Project.run_baseline_model(self, params, derived_outputs_whitelist, build_options)
#      79 """
#      80 Run the project's baseline model with the given parameters.
#      81 Returns the completed baseline model.
#      82 """
#      83 params_dict = params.to_dict()
# ---> 84 model = self.build_model(params_dict, build_options)
#      85 if type(model) is CompartmentalModel and derived_outputs_whitelist:
#      86     # Only calculate required derived outputs.
#      87     model.set_derived_outputs_whitelist(derived_outputs_whitelist)
#
# File C:\autumn\AuTuMN\autumn\models\tb_dynamics\model.py:171, in build_model(params, build_options)
#     168 model.stratify_with(age_strat)
#     170 # Generate outputs
# --> 171 request_outputs(
#     172     model,
#     173     cumulative_start_time,
#     174     BASE_COMPARTMENTS)
#     176 return model
#
# File C:\autumn\AuTuMN\autumn\models\tb_dynamics\outputs.py:31, in request_outputs(model, cumulative_start_time, compartments)
#      27 # Death
#      28 output_builder.request_flow_output(
#      29     "mortality_infectious_raw", "infect_death", save_results=False
#      30 )
# ---> 31 output_builder.request_flow_output(
#      32     "mortality_on_treatment_raw", "treatment_death", save_results=False
#      33 )
#      34 sources = ["mortality_infectious_raw", "mortality_on_treatment_raw"]
#      35 output_builder.request_aggregation_output(
#      36     "mortality_raw",
#      37     sources,
#      38     save_results=False
#      39 )
#
# File C:\autumn\AuTuMN\autumn\models\tb_dynamics\outputs.py:80, in TbOutputBuilder.request_flow_output(self, output_name, flow_name, save_results)
#      79 def request_flow_output(self, output_name, flow_name, save_results=True):
# ---> 80     self.model.request_output_for_flow(output_name, flow_name, save_results=save_results)
#
# File c:\Users\user\anaconda3\envs\autumn\lib\site-packages\summer\model.py:1138, in CompartmentalModel.request_output_for_flow(self, name, flow_name, source_strata, dest_strata, save_results, raw_results)
#    1134     assert name not in self._derived_output_requests, msg
#    1135     is_flow_exists = any(
#    1136         [f.is_match(flow_name, source_strata, dest_strata) for f in self._flows]
#    1137     )
# -> 1138     assert is_flow_exists, f"No flow matches: {flow_name} {source_strata} {dest_strata}"
#    1140 self._derived_output_graph.add_node(name)
#    1141 self._derived_output_requests[name] = {
#    1142     "request_type": DerivedOutputRequest.FLOW,
#    1143     "flow_name": flow_name,
#    (...)
#    1147     "save_results": save_results,
#    1148 }
#
# AssertionError: No flow matches: treatment_death {} {}

# %%
derived_df_0 = model_0.get_derived_outputs_df()

# %%
derived_df_0
# Out:
#         total_population  percentage_latent  prevalence_infectious  \
# 1950.0      33048.000000           0.000000               3.025902
# 1950.1      33076.613366           0.001128               2.927748
# 1950.2      33106.127200           0.002180               2.879268
# 1950.3      33136.525802           0.003192               2.858036
# 1950.4      33167.793873           0.004183               2.852692
# ...                  ...                ...                    ...
# 2019.6      96131.656584          64.084276            1562.353932
# 2019.7      96225.298136          64.105338            1561.059322
# 2019.8      96318.939987          64.126015            1559.801088
# 2019.9      96412.584023          64.146254            1558.627511
# 2020.0      96506.229063          64.166141            1557.471127
#
#         incidence_early  incidence_late  cumulative_deaths  \
# 1950.0         0.000000        0.000000           0.000000
# 1950.1         0.102968        0.000036           0.000000
# 1950.2         0.261950        0.000164           0.000000
# 1950.3         0.350002        0.000382           0.000000
# 1950.4         0.401433        0.000660           0.000000
# ...                 ...             ...                ...
# 2019.6       531.649915       82.926116        8893.940305
# 2019.7       531.724012       83.026180        8923.980812
# 2019.8       532.300403       83.125867        8954.025990
# 2019.9       532.581540       83.225176        8984.076960
# 2020.0       532.629936       83.324114        9014.134657
#
#         cumulative_diseased   incidence
# 1950.0             0.000000    0.000000
# 1950.1             0.000000    0.311412
# 1950.2             0.000000    0.791737
# 1950.3             0.000000    1.057394
# 1950.4             0.000000    1.212302
# ...                     ...         ...
# 2019.6         19512.457644  639.306607
# 2019.7         19573.932663  638.865458
# 2019.8         19635.475290  638.946265
# 2019.9         19697.055961  638.720269
# 2020.0         19758.651366  638.253152
#
# [701 rows x 8 columns]

# %%
fig = px.line(
    derived_df_0,
    x=derived_df_0.index,
    y="percentage_latent",
    labels={'index':'Year', 'percentage_latent':'Latent TB (% of population)'})
fig.show()

# %%
fig = px.line(
    derived_df_0,
    x=derived_df_0.index,
    y="prevalence_infectious",
    labels={'index':'Year', 'prevalence_infectious':'Prevalence of TB (Per hundered thousand)'}
)
fig.show()
